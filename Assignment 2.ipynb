# %%
import pandas as pd

# %%
df = pd.read_csv('Film_Permits.csv', encoding = 'utf-8')

# %%
list(df)
# Out:
# ['EventID',
#  'EventType',
#  'StartDateTime',
#  'EndDateTime',
#  'EnteredOn',
#  'EventAgency',
#  'ParkingHeld',
#  'Borough',
#  'CommunityBoard(s)',
#  'PolicePrecinct(s)',
#  'Category',
#  'SubCategoryName',
#  'Country',
#  'ZipCode(s)']

# %%
df = df.drop(df.columns[11], axis = 1)

# %%
df.describe()
# Out:
#              EventID
# count   44731.000000
# mean   232786.852831
# std    143639.336938
# min     42069.000000
# 25%    116734.000000
# 50%    191498.000000
# 75%    403174.500000
# max    494571.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44731 entries, 0 to 44730
# Data columns (total 13 columns):
# EventID              44731 non-null int64
# EventType            44731 non-null object
# StartDateTime        44731 non-null object
# EndDateTime          44731 non-null object
# EnteredOn            44731 non-null object
# EventAgency          44731 non-null object
# ParkingHeld          44731 non-null object
# Borough              44731 non-null object
# CommunityBoard(s)    44723 non-null object
# PolicePrecinct(s)    44723 non-null object
# Category             44731 non-null object
# Country              44731 non-null object
# ZipCode(s)           44723 non-null object
# dtypes: int64(1), object(12)
# memory usage: 4.4+ MB

# %%
df['StartDateTime'] = pd.to_datetime(df['StartDateTime'])
df['EndDateTime'] = pd.to_datetime(df['EndDateTime'])
df['EnteredOn'] = pd.to_datetime(df['EnteredOn'])

# %%
df.sort_values(by = 'EventID', ascending =  True)
# Out:
#        EventID                      EventType       StartDateTime  \
# 44730    42069  Theater Load in and Load Outs 2012-01-02 07:00:00
# 44729    42287                Shooting Permit 2012-01-05 13:00:00
# 44728    42581                Shooting Permit 2012-01-03 10:00:00
# 44727    42727                Shooting Permit 2012-01-03 08:00:00
# 44726    42737  Theater Load in and Load Outs 2012-01-02 06:00:00
# 44725    42780  Theater Load in and Load Outs 2012-01-02 18:00:00
# 44724    42781  Theater Load in and Load Outs 2012-01-03 00:00:00
# 44723    42804                Shooting Permit 2012-01-09 06:30:00
# 44722    42825                Shooting Permit 2012-01-04 07:00:00
# 44721    42847                Shooting Permit 2012-01-03 07:00:00
# 44720    42923                Shooting Permit 2012-01-03 07:00:00
# 44719    42926  Theater Load in and Load Outs 2012-01-02 06:00:00
# 44718    43049                Shooting Permit 2012-01-05 07:00:00
# ...
